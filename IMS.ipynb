# %% [markdown]
# #IMPORTING JSON AND TIME

# %%
import json
import time

# %% [markdown]
# #CREATING AND SAVING THE VALUES TO RECORDS JSON FILE

# %%
fd=open("records.json","w")
 
PRODUCTS={'100':{"NAME":"PEN","PRICE":"25","QUANTITY":"40","BRAND":"HERO","EXP_DATE":"NONE"},
'101':{"NAME":"PENCIL","PRICE":"5","QUANTITY":"50","BRAND":"APSARA","EXP_DATE":"NONE"},
'102':{"NAME":"MILK","PRICE":"20","QUANTITY":"100","BRAND":"AAVIN","EXP_DATE":"28-09-2021"},
'103':{"NAME":"CANDY","PRICE":"10","QUANTITY":"50","BRAND":"MENTOS","EXP_DATE":"20-03-2022"},
'104':{"NAME":"DATES","PRICE":"100","QUANTITY":"60","BRAND":"LION DATES","EXP_DATE":"20-04-2022"},
'105':{"NAME":"GEMS","PRICE":"5","QUANTITY":"70","BRAND":"CADBURY","EXP_DATE":"21-04-2024"},
'106':{"NAME":"APPLE JUICE","PRICE":"25","QUANTITY":"80","BRAND":"FIZZ","EXP_DATE":"21-04-2022"},
'107':{"NAME":"POPCORN","PRICE":"35","QUANTITY":"60","BRAND":"ACTIVE","EXP_DATE":"28-09-2021"},
'108':{"NAME":"TOMATO SAUCE","PRICE":"50","QUANTITY":"20","BRAND":"NESTLE","EXP_DATE":"12-02-2024"},
'109':{"NAME":"CHILLI SAUCE","PRICE":"45","QUANTITY":"90","BRAND":"NESTLE","EXP_DATE":"19-04-2025"},
'110':{"NAME":"SUGAR","PRICE":"75","QUANTITY":"50","BRAND":"TATA","EXP_DATE":"NONE"},
'111':{"NAME":"DAIRY MILK","PRICE":"15","QUANTITY":"100","BRAND":"CADBURY","EXP_DATE":"20-02-2025"},
'112':{"NAME":"BATTERY","PRICE":"40","QUANTITY":"100","BRAND":"DURACELL","EXP_DATE":"20-06-2008"},
'113':{"NAME":"BOURBAN","PRICE":"20","QUANTITY":"20","BRAND":"ECLARS","EXP_DATE":"12-02-2024"},
'114':{"NAME":"RASANA","PRICE":"5","QUANTITY":"140","BRAND":"GLUCO","EXP_DATE":"04-09-2021"},
'115':{"NAME":"ERASER","PRICE":"2","QUANTITY":"40","BRAND":"NATRAJ","EXP_DATE":"NONE"},
'116':{"NAME":"MANGO JUICE","PRICE":"40","QUANTITY":"90","BRAND":"SLICE","EXP_DATE":"16-09-2026"},
'117':{"NAME":"NOODLES","PRICE":"55","QUANTITY":"90","BRAND":"YIPEE","EXP_DATE":"29-01-2029"},
'118':{"NAME":"EGG","PRICE":"5","QUANTITY":"140","BRAND":"BROILER","EXP_DATE":"NONE"},
'119':{"NAME":"ICE CREAM","PRICE":"25","QUANTITY":"40","BRAND":"AMUL","EXP_DATE":"23-06-2026"},
'120':{"NAME":"KURKURE","PRICE":"15","QUANTITY":"20","BRAND":"PARLE","EXP_DATE":"20-09-2029"},
'121':{"NAME":"JELLY","PRICE":"20","QUANTITY":"10","BRAND":"JELLYBEANS","EXP_DATE":"20-09-2021"},
'122':{"NAME":"BUTTER MILK","PRICE":"15","QUANTITY":"40","BRAND":"SAM","EXP_DATE":"25-05-2017"},
'123':{"NAME":"BOVONTO","PRICE":"25","QUANTITY":"40","BRAND":"KALIMARK","EXP_DATE":"06-08-2021"},
'124':{"NAME":"KIT KAT","PRICE":"85","QUANTITY":"30","BRAND":"NESTLE","EXP_DATE":"20-05-2022"},
'125':{"NAME":"JAM","PRICE":"20","QUANTITY":"40","BRAND":"KISSAN","EXP_DATE":"30-09-2024"},
'126':{"NAME":"THEAN MITTAI","PRICE":"5","QUANTITY":"110","BRAND":"ARASU","EXP_DATE":"17-08-2029"},
'127':{"NAME":"CREAM BISCUIT","PRICE":"35","QUANTITY":"45","BRAND":"MILKBICIS","EXP_DATE":"20-01-2025"},
'128':{"NAME":"ENERGY DRINK","PRICE":"50","QUANTITY":"20","BRAND":"GLUCUPLUS","EXP_DATE":"12-04-2021"},
'129':{"NAME":"PINEAPPLE JUICE","PRICE":"10","QUANTITY":"20","BRAND":"B NATURAL","EXP_DATE":"20-03-2022"},
'130':{"NAME":"CASHEW NUTS","PRICE":"15","QUANTITY":"80","BRAND":"CHARLES","EXP_DATE":"14-08-2028"}}
js=json.dumps(PRODUCTS)
fd.write(js)
fd.close()

# %%
fd=open("records.json","r")
txt=fd.read()
fd.close()
products=json.loads(txt)

# %% [markdown]
# #MENU TO DISPLAY LIST OF PRODUCTS NAME AND PRODUCTS ID

# %%
print("   •••••~~~~~MENU~~~~~•••••")
print("PRODUCT ID \t PRODUCT NAME")
for i in PRODUCTS.keys():
      print(i,"            ",PRODUCTS[i]["NAME"])
# Out:
#    •••••~~~~~MENU~~~~~•••••
# PRODUCT ID 	 PRODUCT NAME
# 100              PEN
# 101              PENCIL
# 102              MILK
# 103              CANDY
# 104              DATES
# 105              GEMS
# 106              APPLE JUICE
# 107              POPCORN
# 108              TOMATO SAUCE
# 109              CHILLI SAUCE
# 110              SUGAR
# 111              DAIRY MILK
# 112              BATTERY
# 113              BOURBAN
# 114              RASANA
# 115              ERASER
# 116              MANGO JUICE
# 117              NOODLES
# 118              EGG
# 119              ICE CREAM
# 120              KURKURE
# 121              JELLY
# 122              BUTTER MILK
# 123              BOVONTO
# 124              KIT KAT
# 125              JAM
# 126              THEAN MITTAI
# 127              CREAM BISCUIT
# 128              ENERGY DRINK
# 129              PINEAPPLE JUICE
# 130              CASHEW NUTS

# %% [markdown]
# #GETTING INPUT FROM USER

# %%
USERID=str(int(input("Enter the product id:")))
QUANTITY=int(input("Enter The Quantity :"))
PRODUCTSID = PRODUCTS.keys
# Out:
# Enter the product id:107
# Enter The Quantity :4

# %%
PRODUCTS.keys()
# Out:
# dict_keys(['100', '101', '102', '103', '104', '105', '106', '107', '108', '109', '110', '111', '112', '113', '114', '115', '116', '117', '118', '119', '120', '121', '122', '123', '124', '125', '126', '127', '128', '129', '130'])

# %% [markdown]
# #THE BILL FOR THE PRODUCT PURCHASED

# %%
 
print("        D-MART            ")
print("---------------------------------  ")
print("  AVENUE SUPERMARTS LTD   ")
print("---------------------------------  ")
print(" DMART KOTTPATU TRICHY\n       BLOCK NO:19  \n   KOTTAPATTU VILLAGE \n DPP-TIRUCHIRAPALLI AIRPORT \n      TRICHY-620004 \n   PHONE:0431-2340380      ")
print("---------------------------------  ")
print("~~~~~~~~~Bill~~~~~~~~~~",end=" ")
print("\nDAY DATE AND TIME :",time.ctime())
print("PRODUCT  :",PRODUCTS[USERID]["NAME"])
print("QUANTITY :",QUANTITY)
print("PRICE  ₹ :",PRODUCTS[USERID]["PRICE"])
print("BILLING AMOUNT :",int(PRODUCTS[USERID]["PRICE"])*QUANTITY)
print("\tTHANK YOU") 
print("_________________________")
PRODUCTS[USERID]["QUANTITY"]=int(PRODUCTS[USERID]["QUANTITY"])-QUANTITY
# Out:
#         D-MART
# ---------------------------------
#   AVENUE SUPERMARTS LTD
# ---------------------------------
#  DMART KOTTPATU TRICHY
#        BLOCK NO:19
#    KOTTAPATTU VILLAGE
#  DPP-TIRUCHIRAPALLI AIRPORT
#       TRICHY-620004
#    PHONE:0431-2340380
# ---------------------------------
# ~~~~~~~~~Bill~~~~~~~~~~
# DAY DATE AND TIME : Mon Sep  6 03:40:29 2021
# PRODUCT  : POPCORN
# QUANTITY : 4
# PRICE  ₹ : 35
# BILLING AMOUNT : 140
# 	THANK YOU
# _________________________

# %%
 PRODUCTS[USERID]["QUANTITY"]
# Out:
# 56

# %%
 int(PRODUCTS[USERID]["PRICE"])*int(QUANTITY)
# Out:
# 140

# %%
 js = json.dumps(PRODUCTS)
 
fd = open("record.json",'w')
fd.write(js)
fd.close()

# %%
{'PRODUCT':USERID,
'QUANITY':QUANTITY,
'AMOUNT':int(PRODUCTS[USERID]["PRICE"]) * QUANTITY}
# Out:
# {'AMOUNT': 140, 'PRODUCT': '107', 'QUANITY': 4}

# %% [markdown]
# #CREATING SALES JSON FILE TO STORE THE LIST OF PURCHASED PRODUCTS

# %%
fd = open("Sales.json",'w')
Sales = {1:{'PRODUCT':USERID,'QUANITY':QUANTITY,'AMOUNT':int(PRODUCTS[USERID]["PRICE"]) * QUANTITY},
2:{'PRODUCT':USERID,'QUANITY':QUANTITY,'AMOUNT':int(PRODUCTS[USERID]["PRICE"]) * QUANTITY},
3:{'PRODUCT':USERID,'QUANITY':QUANTITY,'AMOUNT':int(PRODUCTS[USERID]["PRICE"]) * QUANTITY},
4:{'PRODUCT':USERID,'QUANITY':QUANTITY,'AMOUNT':int(PRODUCTS[USERID]["PRICE"]) * QUANTITY},
5:{'PRODUCT':USERID,'QUANITY':QUANTITY,'AMOUNT':int(PRODUCTS[USERID]["PRICE"]) * QUANTITY},
6:{'PRODUCT':USERID,'QUANITY':QUANTITY,'AMOUNT':int(PRODUCTS[USERID]["PRICE"]) * QUANTITY},
7:{'PRODUCT':USERID,'QUANITY':QUANTITY,'AMOUNT':int(PRODUCTS[USERID]["PRICE"]) * QUANTITY},
8:{'PRODUCT':USERID,'QUANITY':QUANTITY,'AMOUNT':int(PRODUCTS[USERID]["PRICE"]) * QUANTITY},
9:{'PRODUCT':USERID,'QUANITY':QUANTITY,'AMOUNT':int(PRODUCTS[USERID]["PRICE"]) * QUANTITY},
10:{'PRODUCT':USERID,'QUANITY':QUANTITY,'AMOUNT':int(PRODUCTS[USERID]["PRICE"]) * QUANTITY},
11:{'PRODUCT':USERID,'QUANITY':QUANTITY,'AMOUNT':int(PRODUCTS[USERID]["PRICE"]) * QUANTITY},
12:{'PRODUCT':USERID,'QUANITY':QUANTITY,'AMOUNT':int(PRODUCTS[USERID]["PRICE"]) * QUANTITY},
13:{'PRODUCT':USERID,'QUANITY':QUANTITY,'AMOUNT':int(PRODUCTS[USERID]["PRICE"]) * QUANTITY},
14:{'PRODUCT':USERID,'QUANITY':QUANTITY,'AMOUNT':int(PRODUCTS[USERID]["PRICE"]) * QUANTITY},
15:{'PRODUCT':USERID,'QUANITY':QUANTITY,'AMOUNT':int(PRODUCTS[USERID]["PRICE"]) * QUANTITY},
16:{'PRODUCT':USERID,'QUANITY':QUANTITY,'AMOUNT':int(PRODUCTS[USERID]["PRICE"]) * QUANTITY},
17:{'PRODUCT':USERID,'QUANITY':QUANTITY,'AMOUNT':int(PRODUCTS[USERID]["PRICE"]) * QUANTITY},
18:{'PRODUCT':USERID,'QUANITY':QUANTITY,'AMOUNT':int(PRODUCTS[USERID]["PRICE"]) * QUANTITY},
19:{'PRODUCT':USERID,'QUANITY':QUANTITY,'AMOUNT':int(PRODUCTS[USERID]["PRICE"]) * QUANTITY},
20:{'PRODUCT':USERID,'QUANITY':QUANTITY,'AMOUNT':int(PRODUCTS[USERID]["PRICE"]) * QUANTITY},
21:{'PRODUCT':USERID,'QUANITY':QUANTITY,'AMOUNT':int(PRODUCTS[USERID]["PRICE"]) * QUANTITY},
22:{'PRODUCT':USERID,'QUANITY':QUANTITY,'AMOUNT':int(PRODUCTS[USERID]["PRICE"]) * QUANTITY},
23:{'PRODUCT':USERID,'QUANITY':QUANTITY,'AMOUNT':int(PRODUCTS[USERID]["PRICE"]) * QUANTITY},
24:{'PRODUCT':USERID,'QUANITY':QUANTITY,'AMOUNT':int(PRODUCTS[USERID]["PRICE"]) * QUANTITY},
25:{'PRODUCT':USERID,'QUANITY':QUANTITY,'AMOUNT':int(PRODUCTS[USERID]["PRICE"]) * QUANTITY},
26:{'PRODUCT':USERID,'QUANITY':QUANTITY,'AMOUNT':int(PRODUCTS[USERID]["PRICE"]) * QUANTITY},
27:{'PRODUCT':USERID,'QUANITY':QUANTITY,'AMOUNT':int(PRODUCTS[USERID]["PRICE"]) * QUANTITY},
28:{'PRODUCT':USERID,'QUANITY':QUANTITY,'AMOUNT':int(PRODUCTS[USERID]["PRICE"]) * QUANTITY},
29:{'PRODUCT':USERID,'QUANITY':QUANTITY,'AMOUNT':int(PRODUCTS[USERID]["PRICE"]) * QUANTITY},
30:{'PRODUCT':USERID,'QUANITY':QUANTITY,'AMOUNT':int(PRODUCTS[USERID]["PRICE"]) * QUANTITY}}
 
js=json.dumps(Sales)
fd.write(js)
fd.close()

# %%
 Sale = json.dumps(Sales)

# %%
 PRODUCTS[USERID]["QUANTITY"]
# Out:
# 56

# %% [markdown]
# #ADDING NEW ITEM INTO THE EXISTING INVENTORY

# %%
USERID=str(int(input("Enter the product id:")))
NAME=input("enter the name of product:")
PRICE=int(input("Enter the price:"))
QUANTITY=int(input("Enter The Quantity :"))
BRAND=input("enter the brand name:")
EXP_DATE=input("enter the expiry date of the product:")
PRODUCTS[USERID]={"NAME":NAME,"PRICE":PRICE,"QUANTITY":QUANTITY,"BRAND":BRAND,"EXP_DATE":EXP_DATE}
 
js = json.dumps(PRODUCTS)
 
fd = open("record.json",'w')
fd.write(js)
fd.close()
# Out:
# Enter the product id:131
# enter the name of product:PENDRIVE
# Enter the price:200
# Enter The Quantity :100
# enter the brand name:SONY
# enter the expiry date of the product:NONE

# %% [markdown]
# #DISPLAYING THE PRODUCTS AFTER ADDING NEW PRODUCT TO THE INVENTORY

# %%
PRODUCTS
# Out:
# {'100': {'BRAND': 'HERO',
#   'EXP_DATE': 'NONE',
#   'NAME': 'PEN',
#   'PRICE': '25',
#   'QUANTITY': '40'},
#  '101': {'BRAND': 'APSARA',
#   'EXP_DATE': 'NONE',
#   'NAME': 'PENCIL',
#   'PRICE': '5',
#   'QUANTITY': '50'},
#  '102': {'BRAND': 'AAVIN',
#   'EXP_DATE': '28-09-2021',
#   'NAME': 'MILK',
#   'PRICE': '20',
#   'QUANTITY': '100'},
#  '103': {'BRAND': 'MENTOS',
#   'EXP_DATE': '20-03-2022',
#   'NAME': 'CANDY',
#   'PRICE': '10',
#   'QUANTITY': '50'},
#  '104': {'BRAND': 'LION DATES',
#   'EXP_DATE': '20-04-2022',
#   'NAME': 'DATES',
#   'PRICE': '100',
#   'QUANTITY': '60'},
#  '105': {'BRAND': 'CADBURY',
#   'EXP_DATE': '21-04-2024',
#   'NAME': 'GEMS',
#   'PRICE': '5',
#   'QUANTITY': '70'},
#  '106': {'BRAND': 'FIZZ',
#   'EXP_DATE': '21-04-2022',
#   'NAME': 'APPLE JUICE',
#   'PRICE': '25',
#   'QUANTITY': '80'},
#  '107': {'BRAND': 'ACTIVE',
#   'EXP_DATE': '28-09-2021',
#   'NAME': 'POPCORN',
#   'PRICE': '35',
#   'QUANTITY': '60'},
# ...
